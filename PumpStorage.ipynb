# %%
nightMWHP=2
dayMWHP=7
efficiency=.7
cap=300
ProdFunc=(dayMWHP*Cap)-nightMWHP*(Effeciency*(Cap/Effeciency))

# %%
ProdFunc
# Out:
# 1500.0

# %%
def production_function(nightMWHP, dayMWHP, efficiency, cap, water_in_reservoir,fixed_costs, days):
       if water_in_res
        day_production = dayMWHP * cap 
        night_production = nightMWHP*(efficiency*(cap/efficiency))
        production_function = day_production - night_production
        return production_function

# %%
result=production_function(1,12,.8,400)
print(result)
# Out:
# 4400.0

# %%
print(production_function)
# Out:
# <function production_function at 0x0000012834326200>

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import random
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[59], line 2
#       1 import random
# ----> 2 import pd
#
# ModuleNotFoundError: No module named 'pd'

# %%
import random
import pandas as pd

def production_function(efficiency, cap, water_in_reservoir, fixed_cost, days_in_month, min_price=-5, max_price=30, nightMWHPmod=.1, dayMWHPmod=20):
    monthly_revenue = 0
    daily_data = []
    
    for day in range(days_in_month):
            dayMWHP = dayMWHPmod*random.uniform(min_price, max_price)
            nightMWHP = nightMWHPmod*random.uniform(min_price, max_price)
            price_dif=dayMWHP-nightMWHP
            day_info = {
                "Day": day + 1,
                "Day Price (MWHP)": f"{dayMWHP:.2f}",
                "Night Price (MWHP)": f"{nightMWHP:.2f}",
                "Price Difference": f"{price_dif:.2f}",
                "Water in Reservoir (MW)":f"{water_in_reservoir}"
            }   
            if price_dif > 0 and water_in_reservoir> 0:
                water_used = water_in_reservoir
                day_production = water_in_reservoir*dayMWHP
                total_revenue = day_production 
                net_revenue = total_revenue-fixed_cost
                monthly_revenue += net_revenue
                water_used = water_in_reservoir
                water_in_reservoir -=water_used
                day_info["Day Action"]= "Revenue"
                day_info["Net Revenue"]= f"{net_revenue:.2f}"
            else:
                day_info["Day Action"] = "No production"
                day_info["Net Revenue"] = "N/A"
                
            if nightMWHP < dayMWHP:
                res_space = cap - water_in_reservoir
                water_pumped = res_space
                water_in_reservoir+=water_pumped
                day_info["Night Action"] = f"Pumped {water_pumped:.2f} MW into storage"
                 
            else:
                day_info["Night Action"] = "No pumping"
            day_info["Water Left in Reservoir (MW)"] = f"{water_in_reservoir:.2f}"
            daily_data.append(day_info)
        
    return monthly_revenue, daily_data
    df = pd.DataFrame(daily_data)
    print("Production and P&L Summary:")
    print(df)
#Add evaporation
#Add an additional period 
#Add cost of pumping 
#Have a cumulative profit function
#spit out graphs
#include seasonal variance
#include black start pricing 
#flow into a dcf

# %%
production_function(.8,1000,500,20,30)
# Out:
# (8847226.105955463,
#  [{'Day': 1,
#    'Day Price (MWHP)': '224.03',
#    'Night Price (MWHP)': '1.08',
#    'Price Difference': '222.95',
#    'Water in Reservoir (MW)': '500',
#    'Day Action': 'Revenue',
#    'Net Revenue': '111993.50',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 2,
#    'Day Price (MWHP)': '311.50',
#    'Night Price (MWHP)': '0.95',
#    'Price Difference': '310.54',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'Revenue',
#    'Net Revenue': '311475.52',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 3,
#    'Day Price (MWHP)': '342.36',
#    'Night Price (MWHP)': '1.52',
#    'Price Difference': '340.84',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'Revenue',
#    'Net Revenue': '342337.75',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 4,
#    'Day Price (MWHP)': '255.91',
#    'Night Price (MWHP)': '0.31',
#    'Price Difference': '255.60',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'Revenue',
#    'Net Revenue': '255889.68',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 5,
#    'Day Price (MWHP)': '-85.54',
#    'Night Price (MWHP)': '2.91',
#    'Price Difference': '-88.45',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'No production',
#    'Net Revenue': 'N/A',
#    'Night Action': 'No pumping',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 6,
#    'Day Price (MWHP)': '267.24',
#    'Night Price (MWHP)': '-0.26',
#    'Price Difference': '267.50',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'Revenue',
#    'Net Revenue': '267220.72',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 7,
#    'Day Price (MWHP)': '9.10',
#    'Night Price (MWHP)': '1.84',
#    'Price Difference': '7.26',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'Revenue',
#    'Net Revenue': '9079.38',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 8,
#    'Day Price (MWHP)': '313.71',
#    'Night Price (MWHP)': '2.61',
#    'Price Difference': '311.09',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'Revenue',
#    'Net Revenue': '313685.18',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 9,
#    'Day Price (MWHP)': '476.50',
#    'Night Price (MWHP)': '2.74',
#    'Price Difference': '473.76',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'Revenue',
#    'Net Revenue': '476478.43',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 10,
#    'Day Price (MWHP)': '559.93',
#    'Night Price (MWHP)': '-0.40',
#    'Price Difference': '560.33',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'Revenue',
#    'Net Revenue': '559911.91',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 11,
#    'Day Price (MWHP)': '-65.70',
#    'Night Price (MWHP)': '1.33',
#    'Price Difference': '-67.03',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'No production',
#    'Net Revenue': 'N/A',
#    'Night Action': 'No pumping',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 12,
#    'Day Price (MWHP)': '482.80',
#    'Night Price (MWHP)': '1.79',
#    'Price Difference': '481.00',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'Revenue',
#    'Net Revenue': '482776.35',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 13,
#    'Day Price (MWHP)': '39.64',
#    'Night Price (MWHP)': '2.60',
#    'Price Difference': '37.04',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'Revenue',
#    'Net Revenue': '39616.95',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 14,
#    'Day Price (MWHP)': '509.85',
#    'Night Price (MWHP)': '0.03',
#    'Price Difference': '509.82',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'Revenue',
#    'Net Revenue': '509825.51',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 15,
#    'Day Price (MWHP)': '569.45',
#    'Night Price (MWHP)': '1.13',
#    'Price Difference': '568.32',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'Revenue',
#    'Net Revenue': '569431.71',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 16,
#    'Day Price (MWHP)': '243.13',
#    'Night Price (MWHP)': '2.25',
#    'Price Difference': '240.87',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'Revenue',
#    'Net Revenue': '243107.91',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 17,
#    'Day Price (MWHP)': '-67.06',
#    'Night Price (MWHP)': '1.79',
#    'Price Difference': '-68.85',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'No production',
#    'Net Revenue': 'N/A',
#    'Night Action': 'No pumping',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 18,
#    'Day Price (MWHP)': '464.88',
#    'Night Price (MWHP)': '0.49',
#    'Price Difference': '464.39',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'Revenue',
#    'Net Revenue': '464859.33',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 19,
#    'Day Price (MWHP)': '560.82',
#    'Night Price (MWHP)': '0.92',
#    'Price Difference': '559.90',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'Revenue',
#    'Net Revenue': '560795.75',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 20,
#    'Day Price (MWHP)': '560.35',
#    'Night Price (MWHP)': '1.09',
#    'Price Difference': '559.26',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'Revenue',
#    'Net Revenue': '560334.48',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 21,
#    'Day Price (MWHP)': '482.16',
#    'Night Price (MWHP)': '2.01',
#    'Price Difference': '480.14',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'Revenue',
#    'Net Revenue': '482137.57',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 22,
#    'Day Price (MWHP)': '-83.24',
#    'Night Price (MWHP)': '1.24',
#    'Price Difference': '-84.48',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'No production',
#    'Net Revenue': 'N/A',
#    'Night Action': 'No pumping',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 23,
#    'Day Price (MWHP)': '15.48',
#    'Night Price (MWHP)': '-0.10',
#    'Price Difference': '15.58',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'Revenue',
#    'Net Revenue': '15464.61',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 24,
#    'Day Price (MWHP)': '513.96',
#    'Night Price (MWHP)': '2.85',
#    'Price Difference': '511.11',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'Revenue',
#    'Net Revenue': '513936.82',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 25,
#    'Day Price (MWHP)': '242.31',
#    'Night Price (MWHP)': '2.38',
#    'Price Difference': '239.93',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'Revenue',
#    'Net Revenue': '242289.96',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 26,
#    'Day Price (MWHP)': '283.39',
#    'Night Price (MWHP)': '-0.03',
#    'Price Difference': '283.42',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'Revenue',
#    'Net Revenue': '283367.11',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 27,
#    'Day Price (MWHP)': '420.14',
#    'Night Price (MWHP)': '2.94',
#    'Price Difference': '417.20',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'Revenue',
#    'Net Revenue': '420121.73',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 28,
#    'Day Price (MWHP)': '-3.11',
#    'Night Price (MWHP)': '1.43',
#    'Price Difference': '-4.54',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'No production',
#    'Net Revenue': 'N/A',
#    'Night Action': 'No pumping',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 29,
#    'Day Price (MWHP)': '361.78',
#    'Night Price (MWHP)': '2.69',
#    'Price Difference': '359.09',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'Revenue',
#    'Net Revenue': '361756.17',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'},
#   {'Day': 30,
#    'Day Price (MWHP)': '449.35',
#    'Night Price (MWHP)': '2.91',
#    'Price Difference': '446.44',
#    'Water in Reservoir (MW)': '1000',
#    'Day Action': 'Revenue',
#    'Net Revenue': '449332.09',
#    'Night Action': 'Pumped 1000.00 MW into storage',
#    'Water Left in Reservoir (MW)': '1000.00'}])
